# %% [markdown]
# _Máster Universitario en Inteligencia de Negocio_
#
# _Inteligencia de Cliente CRM_
#
#
#
# # Actividad 01: Análisis descriptivo de los datos (EDA) de un CRM
#
# En esta actividad llevaremos a cabo un análisis descriptivo de los datos provenientes del CRM de la empresa GoodTasteMarket.
#
# GoodTasteMarket es una red de supermercados estadounidense con una amplia presencia en el norte de Europa cuya línea de negocio está centrada en productos de alimentación. Con el objetivo de redefinir sus estrategias comerciales y lanzar nuevas campañas de marketing, GoodTasteMarket pone en marcha un proyecto de análisis de los datos procedentes de su CRM a fin de obtener un conocimiento útil sobre el comportamiento de sus clientes y tomar decisiones informadas en el ámbito del marketing mix.
#
# Para llevar a cabo este análisis disponemos de un conjunto de datos en formato .csv denominado **marketing_campaign.csv** con la siguiente descripción:
#
# ## Descripción del dataset:
#
# - **ID**: Identificador único del cliente
# - **Age**: Edad del cliente
# - **Education**: Nivel educativo del cliente
# 0 - 'Basica'
# 1 - 'Secundaria'
# 2 - 'Grado'
# 3 - 'Master'
# 4 - 'Doctorado - PhD'
#
# - **Marital_Status**: Estado civil del cliente
# 0 - 'Soltero/a'
# 1 - 'Pareja de hecho'
# 2 - 'Casado/a'
# 3 - 'Divorciado/a'
# 4 - 'Viudo/a'
#
# - **Income**: Ingresos familiares anuales del cliente
# - **Children**: Número de niños en el hogar del cliente
# - **Seniority**: Antigüedad del cliente en la empresa
# - **Recency**: Número de días transcurridos desde la última compra del cliente
# - **Complain**: Quejas del cliente en los últimos 2 años (1 - si ha realizado alguna, 0 - si no ha realizado ninguna)
# - **MntWines**: Cantidad gastada en vino en los últimos 2 años
# - **MntFruits**: Cantidad gastada en fruta en los últimos 2 años
# - **MntMeatProducts**: Cantidad gastada en carne en los últimos 2 años
# - **MntFishProducts**: Cantidad gastada en pescado en los últimos 2 años
# - **MntSweetProducts**: Cantidad gastada en dulces en los últimos 2 años
# - **MntGoldProds**: Cantidad gastada en productos premium en los últimos 2 años
# - **MntTotalSpent**: Cantidad total gastada en cualquier producto
# - **NumWebPurchases**: Número de compras realizadas a través del sitio web de la empresa
# - **NumCatalogPurchases**: Número de compras realizadas a través de catálogo
# - **NumStorePurchases**: Número de compras realizadas a través de tiendas físicas
# - **NumTotalPurchases**: Número total de compras realizadas por cualquier canal
# - **NumWebVisitsMonth**: Número de visitas al sitio web de la empresa en el último mes

# %% [markdown]
# ### Paso 1. Importamos las librerías y cargamos el dataset

# %%
# Importamos las librerías necesarias
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Cargamos el dataset en Colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57de82cf-a34d-44bb-8681-2de7122fa832" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57de82cf-a34d-44bb-8681-2de7122fa832">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ###Paso 2: Describimos la estructura de los datos y sus principales estadísticas

# %%
# Leemos el dataset
import io
data = pd.read_csv(io.BytesIO(uploaded['marketing_campaign.csv']), sep=',')
data.head(10)
# Out:
#      ID   Income  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  5524  58138.0       58       635         88              546
# 1  2174  46344.0       38        11          1                6
# 2  4141  71613.0       26       426         49              127
# 3  6182  26646.0       26        11          4               20
# 4  5324  58293.0       94       173         43              118
# 5  7446  62513.0       16       520         42               98
# 6   965  55635.0       34       235         65              164
# 7  6177  33454.0       32        76         10               56
# 8  4855  30351.0       19        14          0               24
# 9  5899   5648.0       68        28          0                6
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  NumWebPurchases  ...  \
# 0              172                88            88                8  ...
# 1                2                 1             6                1  ...
# ...

# %%
# Vemos el número de variables e instancias que tiene el dataset
data.shape
# Out:
# (2240, 21)

# %% [markdown]
# **1**. ¿Cuántas variables tiene el dataset?

# %% [markdown]
# **Respuesta:** 21 variables

# %% [markdown]
# **2**. ¿Cuántas instancias tiene el dataset?

# %% [markdown]
# **Respuesta:** 2.240 instancias

# %%
# Generamos estadísticas descriptivas  de los datos
data.describe()
# Out:
#                  ID         Income      Recency     MntWines    MntFruits  \
# count   2240.000000    2216.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821   52247.251354    49.109375   303.935714    26.302232
# std     3246.662198   25173.076661    28.962453   336.597393    39.773434
# min        0.000000    1730.000000     0.000000     0.000000     0.000000
# 25%     2828.250000   35303.000000    24.000000    23.750000     1.000000
# 50%     5458.500000   51381.500000    49.000000   173.500000     8.000000
# 75%     8427.750000   68522.000000    74.000000   504.250000    33.000000
# max    11191.000000  666666.000000    99.000000  1493.000000   199.000000
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# count      2240.000000      2240.000000       2240.000000   2240.000000
# mean        166.950000        37.525446         27.062946     44.021875
# std         225.715373        54.628979         41.280498     52.167439
# ...

# %% [markdown]
# **3**. Analizad en términos generales la distribución de los datos. Para llevar a cabo este análisis podéis haceros preguntas como: ¿Existe algún dato faltante? ¿Hay alguna media que nos resulte extraña o atípica? ¿El min y max de alguna de las variables os sugiere que puedan existir outliers? ¿Hemos observado alguna variable cuya concentración de los datos, cuartiles 25%, 50%, 75%, os resulte relevante para el análisis? **texto en negrita**

# %% [markdown]
# **¿Existe algún dato faltante?
# R/ en la variante 'Income' se identifica que hacen faltan 24 registros , puesto que se observa que el count tiene 2216 de los 2240 instancias.
#
# ¿Hay alguna media que nos resulte extraña o atípica?
# R/ los Ingresos familiares anuales mínimos de los clientes son 1730 euros y los maximos son de 666666 euros, con una media de 52247,25 euros se observa que se encuentra muy cercana al valor mínimo y muy alejada del valor máximo, lo que puede significar la presencia de datos atipicos, adicionalmente, si se analiza la desviación estándar de 25173,07 , es muy alta, lo que significa la presencia de datos dispersos.
#
# ¿El min y max de alguna de las variables os sugiere que puedan existir outliers?
# R/ Se encuentra que el dato máximo de la variable 'Income' puede presentar  outliers, ya que entre el valor de la media y el valor máximo se evidencia una diferencia de 614.419, superando en gran medida la desviación estándar de esta variable.
# de igual forma Se encuentra que el dato máximo de la variable 'Age' puede presentar  outliers, ya que entre el valor de la media y el valor máximo se evidencia una diferencia de 75,81, superando en 63,83 años la desviacion estandar la cual es de 11,98.
#
# ¿Hemos observado alguna variable cuya concentración de los datos, cuartiles 25%, 50%, 75%, os resulte relevante para el análisis?
# R/
# Las ventas de vino, carne, pescado, incluso dulces, se puede ver afectado por variables como 'Income', por esta razón pueden existir saltos grandes entre el Percentil 50,Percentil 75 y los valores maximos.
# por ejemplo en la variable 'MntTotalSpent' en el percentil 50 se identifica un valor de 396 euros, en el percentil 75 , 1045 euros y un valor maximo de 2525, lo que puede significar que el 75% del total de los clientes gastan 217,5 euros menos de la mitad del valor maximo gastado por un cliente.
#
# **

# %%
#Generamos estadísticas de una variable concreta, la variable "Income"
data['Income'].describe()
# Out:
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name: Income, dtype: float64

# %% [markdown]
# **4**. Analizad los principales estadísticos de la variable **"Income"**: mean, std, min, cuartiles 25%, 50% 75% y max. Para llevar a cabo este análisis podéis responder a preguntas como :¿La media de ingresos es más/menos elevada? ¿Cuál es el rango de ingresos en el que se encuentra el 50% de los clientes?

# %% [markdown]
# **¿La media de ingresos es más/menos elevada?**
#
# - R/ La media de los ingresos es muy similar a la mediana de los datos, que se ubica en 51.381
#
# **¿Cuál es el rango de ingresos en el que se encuentra el 50% de los clientes?**
#
# - R/ El rango está entre 1.730 y 51.381,5

# %%
#Vemos qué tipo de variables contiene el dataset y qué valores no contienen nulos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Income               2216 non-null   float64
#  2   Recency              2240 non-null   int64
#  3   MntWines             2240 non-null   int64
#  4   MntFruits            2240 non-null   int64
#  5   MntMeatProducts      2240 non-null   int64
#  6   MntFishProducts      2240 non-null   int64
#  7   MntSweetProducts     2240 non-null   int64
#  8   MntGoldProds         2240 non-null   int64
#  9   NumWebPurchases      2240 non-null   int64
#  10  NumCatalogPurchases  2240 non-null   int64
#  11  NumStorePurchases    2240 non-null   int64
#  12  NumWebVisitsMonth    2240 non-null   int64
#  13  Complain             2240 non-null   int64
#  14  Education_Int        2240 non-null   int64
# ...

# %% [markdown]
# **5**. ¿Cuántas variables numéricas tiene el dataset? ¿Cuántas de tipo caracter o string?

# %% [markdown]
# **Respuesta** :
# - R/ El dataset cuenta con 21 variables numericas, de las cuales 20 variables son de tipo numero entero y 1 variable de tipo numero decimal. El dataset no cuenta con variables tipo string.

# %% [markdown]
# **6**. ¿Existen valores nulos en el dataset? ¿Si es así, en qué variables?

# %% [markdown]
# **Respuesta:**
# - R/ si, en la variable 'Income' existen 24 valores nulos

# %%
#Elegimos la variable "Complain" para ver los distintos valores que adopta y saber qué tipo de variable es
print('Complain: ',data['Complain'].unique())
# Out:
# Complain:  [0 1]

# %% [markdown]
# **7**. ¿Pensáis que la variable "Complain" es una variable categórica? Justificad vuestra respuesta.

# %% [markdown]
# **Respuesta:**
# - R/ Es una variable categórica, dado que contiene solo los valores 0 y 1, que se homologan a la categoría "No ha presentado quejas en los últimos 2 años" y "Si ha presentado quejas en los últimos 2 años" respectivamente.

# %%
#Visualizamos los histogramas de las variables numéricas para conocer su distribución
data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
#Visualizamos el histograma de la variable Age
plt.figure(figsize=(12, 10))
plt.hist(data['Age'], bins=25);

# %% [markdown]
#  **8**.  Analizad la visualización del histograma. Podéis apoyaros en preguntas como ¿Qué edad predomina entre los clientes? ¿Cual es la edad de los clientes más jóvenes? ¿Y la de los más mayores? ¿Existe algún dato anómalo que pueda desvirtuar el análisis?

# %% [markdown]
# **Respuesta**:
# - ¿Qué edad predomina entre los clientes?
# R/ Aproximandamente entre los 45-55
# - ¿Cual es la edad de los clientes más jóvenes?
# R/ Aproximadamente entre los 25-30 años
# - ¿Y la de los más mayores?
# R/ aunque se evidencian clientes con una edad superior a 120 años, en la concentracion de los clientes, la edad de las personas mayores esta entre 80 y 85.
# - ¿Existe algún dato anómalo que pueda desvirtuar el análisis?
# R/ La edad de los clientes superior a 120, ya que es muy extraño esas edad en clientes.

# %% [markdown]
# **9**. Escribid el código necesario para visualizar el histograma de la variable "MntWines".

# %%
#Dibujamos el histograma de la variable "MNWines"
plt.figure(figsize=(12, 10))
plt.hist(data['MntWines'], bins=25);

# %% [markdown]
#  **10**. ¿Que nos dice el histograma sobre la distribución de esta variable?

# %% [markdown]
# **Respuesta:**
# - ¿Que nos dice el histograma sobre la distribución de esta variable?
# R/ el comportamiento del histograma describe una tendencia de una funcion reciproca (y =1/x) donde X es cantidas gastada de productos de vino de los clientes y Y el numero de compradores.
# lo anterior se traduce en que la mayoria de los clientes gasta una menor cantidad en productos de vino y la minoria de los clientes gasta una menor cantidad en productos de vino.
# analizando los datos, se observa que los valores máximos de las cantidades gastadas en vino no están alejados a los comportamientos de compra que esperaría regularmente la empresa con este producto, por lo tanto, no sería conveniente considerarlos como outliers.

# %% [markdown]
# ###Paso 3: Realizamos la limpieza de datos: Identificación de valores nulos e imputación de valores faltantes

# %%
#Visualizamos el total de valores nulos de las variables del dataset
data.isnull().sum()
# Out:
# ID                      0
# Income                 24
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Complain                0
# Education_Int           0
# Marital_Status_Int      0
# Children                0
# MntTotalSpent           0
# Age                     0
# NumTotalPurchases       0
# Seniority               0
# dtype: int64

# %% [markdown]
# **11**. ¿Qué variables contienen valores nulos y qúé número de valores nulos?

# %% [markdown]
# **Respuesta:**
# - R/ la variable Income contiene valores nulos , un total de 24

# %% [markdown]
# **12**. ¿Qué estrategias podemos llevar a cabo para hacer frente a la existencia de valores nulos o faltantes en una variable? ¿Cual de ellas elegiríais? Justificad vuestra elección.

# %% [markdown]
# **Respuesta:** podemos eliminar, reemplazar o ignorar en cuanto a estos valores nulos.
# 1. reemplazar : se podria reemplazar los valores nulos con el valor de la media de la variable 'Income'
# 2. eliminar : puesto que los datos faltantes no son representativos respecto al total de los datos al ser el 1,07 % de los datos.
#
# se sugiere optar por opcion 2 'eliminar' dadas las razones anteriores

# %% [markdown]
# ### Paso 4. Análisis de la relación entre variables

# %%
#Realizamos la matriz de correlación entre las variables
correlation_matrix = data.corr(method ='pearson')

# Crear un mapa de calor con seaborn
plt.figure(figsize=(15,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlación (Valores por encima del umbral)')
plt.show()

# %% [markdown]
# **13**. ¿Que información sobre la relación entre las variables que componen el dataset nos proporciona la matriz de correlación? Describe qué es una matriz de correlación y para qué sirve.

# %% [markdown]
# **Respuesta:**
#
# - ¿Que información sobre la relación entre las variables que componen el dataset nos proporciona la matriz de correlación? Describe qué es una matriz de correlación y para qué sirve.
# R/ es un grafico que muestra el coeficiente de correlación entre diferentes variables de un conjunto de datos.
# +1: Correlación positiva perfecta. A medida que una variable aumenta, la otra también lo hace de forma proporcional.
# 0: Sin correlación. No hay ninguna relación lineal entre las variables.
# -1: Correlación negativa perfecta. A medida que una variable aumenta, la otra disminuye de forma proporcional.

# %% [markdown]
# **14**. Analiza los resultados de la matriz de correlación. Para llevar a cabo este análisis podéis plantearos preguntas cómo :¿Existe una relación fuerte entre variables? ¿Qué variables son estas? ¿Qué repercusión tiene para el análisis que las variables tengan una elevada correlación positiva/negativa?...

# %% [markdown]
# **Respuesta:**
# - ¿Existe una relación fuerte entre variables? ¿Qué variables son estas?
# R/
#
# Relacion positiva
# MntTotalSpent VS MntWines correlacion (0,89)
# NumTotalPurchases VS NumStorePurchases correlacion (0,86)
# MntTotalSpent VS MntMeatProducts correlacion (0,84)
#
# Relacion negativa
#
# NumWebVisitsMonth VS Income correlacion (-0,55)
# NumWebVisitsMonth VS MntMeatProducts correlacion (-0,54)
#
#
# - ¿Qué repercusión tiene para el análisis que las variables tengan una elevada correlación positiva/negativa?
#
# R/ se deben generar estrategias para mantener las relaciones positivas como : aumentar la oferta de productos de carne y vino en las tiendas fisicas y de otra manera optar por nuevas estrategias para mejorar las relaciones negativas entre variables, por ejemplo la inversion en la pagina web se debe evaluar frente a la venta de productos perecedores como la carne ya que la correlacion del mapa de calor indica que no se venden estos productos por la pagina web, lo que puede generar perdidas en este canal de venta.

# %% [markdown]
# ### Paso 5. Análisis de outliers

# %%
# Visualizamos los outliers en cada una de las variables utilizando un boxplot
plt.figure(figsize=(15, 8))
sns.boxplot(data=data)
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para una mejor visualización
plt.title('Diagrama de Caja para Detectar Outliers')
plt.show()

# %% [markdown]
# **15**. ¿Existen variables que contengan outliers? Indicad cuales. * Si necesitáis verlas en mayor profundidad podéis generar un nuevo bloxpot de la variable en concreto*

# %% [markdown]
# **Respuesta:**
# - R/ la variable 'Income' posee varios outliers por encima de los limites superiores del diagrama

# %% [markdown]
# **16**. En la celda que se encuentra a continuación, escribid el código necesario para generar las estadísticas de las variables que contengan outliers.

# %%
#Generamos estadísticas de las variables que continen outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Income')
plt.xticks(rotation=45)
plt.title(f'Diagrama de Caja de Income')
plt.xlabel('Income')
plt.show()

data['Income'].describe()
# Out:
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name: Income, dtype: float64

# %% [markdown]
# **17**. ¿Qué repercusión tiene para el análisis la existencia de outliers en dichas variables?
#
#
# R/ los valores atípicos pueden distorsionar las medidas de tendencia central (media, mediana, moda) y las medidas de dispersión (rango, desviación estándar, varianza).

# %%
#hacemos una copia de la data

dataclean=data.copy()

#eliminamos los registros nulos 24 valores vacios

dataclean = dataclean.dropna(subset=['Income'])

#eliminanos los valores superiores a 120000 en income

dataclean = dataclean[dataclean['Income'] <= 120000]

#eliminamos los registros con persona mayores a 100 años

dataclean = dataclean[dataclean['Age'] <= 100]

# %%
dataclean.isnull().sum()
# Out:
# ID                     0
# Income                 0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Complain               0
# Education_Int          0
# Marital_Status_Int     0
# Children               0
# MntTotalSpent          0
# Age                    0
# NumTotalPurchases      0
# Seniority              0
# dtype: int64

# %%
dataclean.describe()
# Out:
#                  ID         Income      Recency     MntWines    MntFruits  \
# count   2205.000000    2205.000000  2205.000000  2205.000000  2205.000000
# mean    5585.439456   51622.094785    49.009070   306.164626    26.403175
# std     3247.546423   20713.063826    28.932111   337.493839    39.784484
# min        0.000000    1730.000000     0.000000     0.000000     0.000000
# 25%     2815.000000   35196.000000    24.000000    24.000000     2.000000
# 50%     5455.000000   51287.000000    49.000000   178.000000     8.000000
# 75%     8418.000000   68281.000000    74.000000   507.000000    33.000000
# max    11191.000000  113734.000000    99.000000  1493.000000   199.000000
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# count      2205.000000      2205.000000       2205.000000   2205.000000
# mean        165.312018        37.756463         27.128345     44.057143
# std         217.784507        54.824635         41.130468     51.736211
# ...

# %% [markdown]
# ### Paso 5.  Análisis de variables de interés: Conocimiento de cliente
#
#
# Una vez visto cómo están distribuidos los datos, si existen valores faltantes y anómalos y llevado a cabo las limpiezas y tranformaciones necesarias,  haremos un análisis en mayor profundidad de aquellas variables que consideramos que nos proporcionan información relevante sobre el comportamiento y las características de nuestros clientes . Esta información puede ser:  el gasto en función de su edad, el tipo de canal de venta que más utilizan o el nivel educativo de aquellos que compran un determinado tipo de producto.

# %%
# Analizamos el nivel educativo de los clientes. Para hacerlo visualizamos con un gráfico de torta
counts = dataclean['Education_Int'].value_counts()

# Añadimos la leyenda
labels = ['Grado', 'PhD', 'Master', 'Secundaria', 'Basica']
plt.pie(counts, labels=labels, autopct='%1.1f%%')
# Añadimos el titulo
plt.title('Distribucion educativa de nuestros clientes')
# Dibujamos el gráfico
plt.show()

# %%
# Analizamos el estado civil de los clientes. Para hacerlo visualizamos con un gráfico de torta
counts = dataclean['Marital_Status_Int'].value_counts()

# Añadimos la leyenda
labels = ['Soltero', 'Pareja de hecho', 'Casado', 'Divorciado', 'Viudo']
plt.pie(counts, labels=labels, autopct='%1.1f%%')
# Añadimos el titulo
plt.title('Estado civil')
# Dibujamos el gráfico
plt.show()

# %%
#Analizamos la relación entre el estado civil del cliente y el gasto y lo representamos gráficamente.
To_Plot = [ "Marital_Status_Int", "MntTotalSpent"]
print("Relación entre las variables seleccionadas")
plt.figure()
# Crear un pairplot con las combinaciones de las variables seleccionadas
sns.pairplot(data[To_Plot])
# Mostrar el pairplot
plt.show()
# Out:
# Relación entre las variables seleccionadas

# %%
# Analizamos la relación entre el número de hijos y el gasto total. Visulizamos con un gráfico de caja

# Seleccionamos el tamaño de la figura
plt.figure(figsize = (10, 6))

# Creamos el dibujo de violin
sns.violinplot(x = 'Children', y = 'MntTotalSpent', data = data, palette = 'cool')

# Definimos el titulo de la figura y de cada eje
plt.title('Distribucion del gasto en función del número de hijos en la familia')
plt.xlabel('Nº Hijos')
plt.ylabel('Gasto Total')

plt.show()
# Out:
# <ipython-input-24-a6d13bc21432>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Children', y = 'MntTotalSpent', data = data, palette = 'cool')

# %%
# Analizamos la relación entre los ingresos de la unidad familiar (Income) y el gasto (MntTotalSpent). Visualizamos con un diagrama de dispersión

# Definimos el tamaño de la figura
plt.figure(figsize = (10, 6))

# Creamos la visualizacion, de tipo scatter plot
plt.scatter(dataclean['Income'], dataclean['MntTotalSpent'], color = 'blue', alpha = 0.1)

# Definimos la leyenda del gráfico
plt.xlabel('Income')
plt.ylabel('MntTotalSpent')

# Definimos el título del gráfico
plt.title('Income vs Time MntTotalSpent')
plt.show()

# %%
#Analizamos la relación entre el nivel educativo del cliente y el gasto
sns.barplot(x = dataclean['Education_Int'],y = dataclean['MntTotalSpent']);
plt.title('Gasto total en función del nivel educativo del cliente');

# %%
#Analizamos la relación entre el gasto y el las quejas planteadas por el cliente.
sns.barplot(x = dataclean['Complain'],y = dataclean['MntTotalSpent'].mean());
plt.title('Gasto medio en función de si el cliente ha presentado o no reclamaciones');

# %%
# Analizamos las ventas por tipo de producto. Lo visualizamos con un gráfico de barras
suma_columna1 = dataclean['MntWines'].sum()
suma_columna2 = dataclean['MntFruits'].sum()
suma_columna3 = dataclean['MntMeatProducts'].sum()
suma_columna4 = dataclean['MntFishProducts'].sum()
suma_columna5 = dataclean['MntSweetProducts'].sum()
suma_columna6 = dataclean['MntGoldProds'].sum()

# Crear un DataFrame con las sumas de cada columna
df_suma = pd.DataFrame({'Columna': ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds'],
                        'Suma': [suma_columna1, suma_columna2, suma_columna3, suma_columna4, suma_columna5, suma_columna6]})

# Crear el gráfico de barras para la suma de cada columna
plt.figure(figsize=(10, 6))
df_suma.plot(x='Columna', y='Suma', kind='bar', color='skyblue')
plt.xlabel('Productos')
plt.ylabel('Cantidad gastada')
plt.title('Ventas totales de cada producto')
plt.show()

# %%
# Analizamos las ventas por canal. Lo visualizamos con un gráfico de barras
suma_columna1 = dataclean['NumWebPurchases'].sum()
suma_columna2 = dataclean['NumCatalogPurchases'].sum()
suma_columna3 = dataclean['NumStorePurchases'].sum()

# Crear un DataFrame con las sumas de cada columna
df_suma = pd.DataFrame({'Columna': ['NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases'],
                        'Suma': [suma_columna1, suma_columna2, suma_columna3]})

# Crear el gráfico de barras para la suma de cada columna
plt.figure(figsize=(10, 6))
df_suma.plot(x='Columna', y='Suma', kind='bar', color='skyblue')
plt.xlabel('Canal')
plt.ylabel('Nº de Ventas')
plt.title('Nº de Ventas totales en cada canal')
plt.show()

# %% [markdown]
# **18**. Realiza los análisis o comparativas de al menos dos variables que consideréis que pueden enriquecer el el análisis y ser útiles para el planteamiento de nuevas estrategias comerciales en el ámbito de las 4P

# %%
#grafico de dispersion edad vs cantidad de vino
sns.scatterplot(data=dataclean, x='Age', y='MntWines')
# Añadir título y etiquetas
plt.title('Cantidad de vino Comprada por Edad')
plt.xlabel('Age')
plt.ylabel('MntWines')

# Mostrar gráfico
plt.show()

# %%
# Define los intervalos de edad
bins = [0, 18, 30, 40, 50, 60, 100]
# Etiquetas para los rangos
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '60-100']

data['rango_edad'] = pd.cut(dataclean['Age'], bins=bins, labels=labels, right=False)

#grafico de vino comprado por edad
vino_edad = data.groupby('rango_edad')['MntWines'].sum().reset_index()

# Crear el gráfico de barras
sns.barplot(x='rango_edad', y='MntWines', data=vino_edad)

# Añadir título y etiquetas
plt.title('Gastos Totales por Edad')
plt.xlabel('Edad')
plt.ylabel('Gasto Total de vino')
# Mostrar gráfico
plt.show()
# Out:
# <ipython-input-82-6ffc0065826d>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   vino_edad = data.groupby('rango_edad')['MntWines'].sum().reset_index()

# %%
# aporte de canal de ventas por edad

# Crear un DataFrame
df = pd.DataFrame(dataclean)

bins = [0, 18, 30, 40, 50, 60,70,85]

# Etiquetas para los rangos
labels = ['0-18', '19-30', '31-40', '41-50', '51-60','61-70','71-85']

dataclean['rango_edad'] = pd.cut(dataclean['Age'], bins=bins, labels=labels, right=False)

# Agrupar por 'Grupo de Edad' y 'Canal' y contar las compras
df_grouped = dataclean.groupby(['rango_edad'])[['NumWebPurchases','NumCatalogPurchases','NumStorePurchases']].sum()

# Crear el gráfico de barras apiladas
df_grouped.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#FF5733', '#33FF57', '#3357FF'])

# Agregar etiquetas y título
plt.xlabel('Grupo de Edad')
plt.ylabel('total de Compras')
plt.title('Distribución de Compras por Canal de Ventas y Grupo de Edad')

# Mostrar la leyenda
plt.legend(title="Canal de Venta")

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-92-55a8557a2b37>:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = dataclean.groupby(['rango_edad'])[['NumWebPurchases','NumCatalogPurchases','NumStorePurchases']].sum()

# %%
# Crear un DataFrame
df = pd.DataFrame(dataclean)

bins = [0, 18, 30, 40, 50, 60,70,85]

# Etiquetas para los rangos
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '61-70','71-85']

dataclean['rango_edad'] = pd.cut(dataclean['Age'], bins=bins, labels=labels, right=False)

# Agrupar por 'Grupo de Edad' y 'productos' y contar las compras
df_grouped = dataclean.groupby(['rango_edad'])[['MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']].sum()

# Crear el gráfico de barras apiladas
df_grouped.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#FF0027', '#33FF57', '#3357FF','#FFEF00', '#FF00B1', '#FF8300'])

# Agregar etiquetas y título
plt.xlabel('Grupo de Edad')
plt.ylabel('Tipo de producto')
plt.title('Distribución de Compras por tipo de producto y Grupo de Edad')

# Mostrar la leyenda
plt.legend(title="Total gastado en productos")

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-90-b89556ca212c>:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = dataclean.groupby(['rango_edad'])[['MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']].sum()

# %%
# Agrupar por nivel de educación y sumar el gasto en cada tipo de producto
gasto_por_educacion = dataclean.groupby('Education_Int')[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].sum()
# Crear un gráfico de barras apiladas
gasto_por_educacion.plot(kind='bar', stacked=True, figsize=(12, 8))
# Añadir título y etiquetas
plt.title('Suma del gasto de los clientes por tipo de producto y nivel de educación')
plt.xlabel('Nivel de Educación')
plt.ylabel('Suma del Gasto')
plt.legend(title='Tipo de Producto')
plt.show()

# %%
# Gráfico de dispersión ingresos contra edad

income = dataclean['Income']

age = dataclean['Age']

# Crear el gráfico de dispersión

plt.scatter(age, income, color='blue', marker='o')

# Agregar etiquetas a los ejes

plt.xlabel('Edad')

plt.ylabel('Ingresos')

plt.title('Gráfico de Dispersión: Ingresos vs Edad')

# Mostrar el gráfico

plt.show()

# %%
# Analizamos la proporción de clientes con o sin hijos. Para hacerlo visualizamos con un gráfico de torta
counts = dataclean['Children'].value_counts()

# Añadimos la leyenda
labels = ['0', '1', '2', '3']
plt.pie(counts, labels=labels, autopct='%1.1f%%')
# Añadimos el titulo
plt.title('Hijos')
# Dibujamos el gráfico
plt.show()

# %% [markdown]
# ### Paso 6:  Informe de resultados y conclusiones
#
# **19**. Elaborad un informe que contenga una descripción del **análisis de los datos** que habéis realizado. Este informe debe contener como mínimo los siguientes aspectos:
#
# - Descripción de la tipología de cliente (edad, estado civil,número de hijos...)
# - Descripción del comportamiento del cliente (productos que compran, canales de venta que utilizan)
# - Detalle de los resultados o conclusiones alcanzadas en el análisis.
#
# Para realizar este informe será necesario que analicéis otras variables de interés además de las ya analizadas. Podéis apoyaros para ello en la creación de visualizaciones, son de gran ayuda.

# %%
# Analizamos la relación entre el número de hijos y el gasto total en vino. Visulizamos con un gráfico de caja

# Seleccionamos el tamaño de la figura
plt.figure(figsize = (10, 6))

# Creamos el dibujo de violin
sns.violinplot(x = 'Children', y = 'MntWines', data = dataclean, palette = 'cool')

# Definimos el titulo de la figura y de cada eje
plt.title('Distribucion del gasto en vino en función del número de hijos en la familia')
plt.xlabel('Nº Hijos')
plt.ylabel('Gasto Total')

plt.show()
# Out:
# <ipython-input-33-b691edd46cbd>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Children', y = 'MntWines', data = dataclean, palette = 'cool')

# %%
# Analizamos la relación entre el número de hijos y el gasto total en carne. Visulizamos con un gráfico de caja

# Seleccionamos el tamaño de la figura
plt.figure(figsize = (10, 6))

# Creamos el dibujo de violin
sns.violinplot(x = 'Children', y = 'MntMeatProducts', data = dataclean, palette = 'cool')

# Definimos el titulo de la figura y de cada eje
plt.title('Distribucion del gasto en carne en función del número de hijos en la familia')
plt.xlabel('Nº Hijos')
plt.ylabel('Gasto Total')

plt.show()
# Out:
# <ipython-input-34-64397901e41b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Children', y = 'MntMeatProducts', data = dataclean, palette = 'cool')

# %%
dataclean.describe()
# Out:
#                  ID         Income      Recency     MntWines    MntFruits  \
# count   2205.000000    2205.000000  2205.000000  2205.000000  2205.000000
# mean    5585.439456   51622.094785    49.009070   306.164626    26.403175
# std     3247.546423   20713.063826    28.932111   337.493839    39.784484
# min        0.000000    1730.000000     0.000000     0.000000     0.000000
# 25%     2815.000000   35196.000000    24.000000    24.000000     2.000000
# 50%     5455.000000   51287.000000    49.000000   178.000000     8.000000
# 75%     8418.000000   68281.000000    74.000000   507.000000    33.000000
# max    11191.000000  113734.000000    99.000000  1493.000000   199.000000
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# count      2205.000000      2205.000000       2205.000000   2205.000000
# mean        165.312018        37.756463         27.128345     44.057143
# std         217.784507        54.824635         41.130468     51.736211
# ...

# %%
# Analizamos la relación entre el nivel de educación y el gasto total. Visulizamos con un gráfico de caja

# Seleccionamos el tamaño de la figura
plt.figure(figsize = (10, 6))

# Creamos el dibujo de violin
sns.violinplot(x = 'Education_Int', y = 'MntWines', data = dataclean, palette = 'cool')

# Definimos el titulo de la figura y de cada eje
plt.title('Distribucion del gasto en función vino del nivel de educación')
plt.xlabel('Grado de educación')
plt.ylabel('Gasto Total')

plt.show()
# Out:
# <ipython-input-37-d5ce24601b35>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Education_Int', y = 'MntWines', data = dataclean, palette = 'cool')

# %%
# Creamos el dibujo de violin
sns.violinplot(x = 'Education_Int', y = 'MntMeatProducts', data = dataclean, palette = 'cool')

# Definimos el titulo de la figura y de cada eje
plt.title('Distribucion del gasto en función carne del nivel de educación')
plt.xlabel('Grado de educación')
plt.ylabel('Gasto Total')

plt.show()
# Out:
# <ipython-input-38-f748adbe79cf>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Education_Int', y = 'MntMeatProducts', data = dataclean, palette = 'cool')

# %%
#grafico de dispersión Quejas vs Cantidad total de compras por cualquier canal
sns.scatterplot(data=dataclean, x='Complain', y='NumTotalPurchases')
# Añadir título y etiquetas
plt.title('Quejas Vs Número total de compras por cualquier canal')
plt.xlabel('Complain')
plt.ylabel('NumTotalPurchases')

# Mostrar gráfico
plt.show()

# %%
# Analizamos la relación entre el número de hijos y el gasto total en vino. Visulizamos con un gráfico de caja

# Seleccionamos el tamaño de la figura
plt.figure(figsize = (10, 6))

# Creamos el dibujo de violin
sns.violinplot(x = 'Marital_Status_Int', y = 'MntWines', data = dataclean, palette = 'cool')

# Definimos el titulo de la figura y de cada eje
plt.title('Distribucion del gasto en vino en función del estado civil')
plt.xlabel('Estado civil')
plt.ylabel('Gasto Total de vino')

plt.show()
# Out:
# <ipython-input-40-d6432d99488e>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Marital_Status_Int', y = 'MntWines', data = dataclean, palette = 'cool')

# %% [markdown]
# - **Descripcion de la tipologia:**
#
# se denota que la mayoria de clientes se encuentran entre los 45 y 60 , con una edad promedio de 54,19 años = 54 años.
#
# en cuanto a su nivel educativo se denota que del total de registros 88,5 % de los clientes poseen al menos un titulo universitario.
#
# en cuanto a su estado civil 38,8% estan solteros, 25,8 % tienen pareja de hecho,21,5% estan casados ,10,4% estan divorciados 3,4% estan viudos.
#
# en cuanto al numero de hijos se observa que el 50,4 % de los clientes no tienen hijos y que el restante 49,6 % tienen al menos un hijo.
#
# en cuanto a los ingresos no existe una variacion significativa en funcion de los segmentos de edad. es decir que clientes de todas las edades tienen ingresos entre altos y bajos.
#
# - **Descripcion del comportamiento y Conclusiones**
#
# De acuerdo con los datos, los productos en que los clientes de GoodTasteMarket más han gastado son el vino, seguido de la carne. Y en los que menos han gastado son en las frutas y los dulces. También, es importante resaltar que, para los productos premium, se observa que los clientes gastan una cantidad más cercana a los productos con menor gasto, comportamiento que puede no ser el esperado para este tipo de productos.
#
# La tienda tiene 3 medios de venta:
# NumWebPurchases: 4.084821 = 4.10
# NumStorePurchases: 5.790179 = 5.80
# NumCatalogPurchases:  2.66205 = 2.70
#
# es importante resaltar, que analizando el numero de compras por canal de acuerdo al rango de edad de los clientes, se encuentra que para todos los rangos analizados hay un comportamiento similar en cuanto a la preferencia de los canales de venta, siendo el canal preferente la tienda física, seguido de la web y por último el catalogo.
#
# aquellos clientes que no tienen hijos, se evidencia un compartamiento de compras superior en los productos de carne y vino, al compararlos contra aquellos clientes que tienen hijos. lo cual no es lo que se esperaria al aumentar el nucleo familiar de los clientes.
#
# Se identifica que a mayor nivel de educación mayor es el gasto de vino. En cuanto al gasto de carne de acuerdo con el grado de educación no se evidencia diferencias significativas en el gasto de los clientes.
#
# En cuanto el gasto en vino en función del estado civil se observa que los clientes con estado civil viudo son aquellos que presentan niveles de gastos mayores en este producto, sin embargo, es importante resaltar que son los clientes que en cantidad representan solo el 3,4% del total de los clientes. En cuanto a los clientes con estado civil solteros, parejas de hecho y casados, no se observan marcadas diferencias entre estos en función del gasto en vino.

# %% [markdown]
# ### Paso 7: Propuesta para el lanzamiento de nuevas estrategias comerciales
# **20**.  Elaborad una propuesta con al menos 3 recomendaciones para el lanzamiento de nuevas estrategias comerciales en el ámbito del marketing mix y las 4P (producto, precio, distribución y comunicación).
# Esta propuesta debe estar basada y justificada en el análisis de los datos disponibles que hemos realizado. **Es importante que baséis vuestras recomendaciones en datos, datos concretos y dentro del dominio del problema que tratamos de resolver**. Esta propuesta debe contener como mínimo los siguientes aspectos:
#
# - Oportunidades comerciales que habéis identificado en base al análisis realizado.
# - Recomendaciones de estrategias comerciales en torno a las 4P. Estas pueden estar orientadas por ejemplo a ajustes en la oferta y la demanda, estrategias de precio en función del segmento...etc.

# %% [markdown]
# 1. UBICACIÓN ESTRATÉGICA DE PRODUCTOS DE ALTO GASTO EN TIENDA FÍSICA: dado que el canal preferido por los clientes es la tienda física, sería conveniente ubicar estratégicamente los vinos y las carnes, ya que representan un gasto mayor. Además, al identificar que el consumo de estos productos es más significativo para clientes sin hijos, vale la pena considerar si se pueden adaptar espacios premium o exclusivos dentro de la tienda física para este tipo de clientes, ofreciendo productos exclusivos en esta categoría, por ejemplo, vinos especiales. También por el nicho de clientes la tienda puede crear estrategias especializadas para potencializar la compra de estos productos en este nicho, por ejemplo, programar cata de vinos, que se acompañen con productos como quesos y carnes, que se pueden ofrecer como "Paquetes premium", incentivando la compra de estos.
# A su vez, considerando que la mayoría de los clientes tienen al menos un titulo de grado profesional, se sugiere implementar campañas educativas que destaquen los beneficios y características de los productos, con el objetivo de aumentar la percepción de valor en el segmento de clientes con estos niveles de educación.
#
#
# 2. PROMOCIONAR CANAL WEB: Dado que el gasto en línea es secundario, se recomienda verificar los productos con mayor gasto en este canal, con el objetivo de potencializar las compras de estos, pudiendo incentivar las compras de productos no perecederos, ya que se evidenciaron las correlaciones más fuertes negativas sobre estos. Se sugiere mejorar la experiencia del cliente en la página, también se pueden generar recomendaciones personalizadas según el historial de compras y perfil de cliente. También se recomienda implementar ofertas especiales para productos seleccionados que solo sean accesibles en el canal en línea para incentivando a los clientes que visitan frecuentemente al sitio web, pero no compran.
#
# Otra estrategias en este canal serían:
#
# - La implementación de un Programa de fidelización de clientes, donde las compras en línea acumulen puntos canjeables por descuentos en futuras compras o envíos gratuitos.
# - Ofrecer opciones flexibles como entregas rápidas (24 horas o menos)
# Envíos gratuitos para pedidos superiores a un monto mínimo.
# - Implementar una opción de click & collect para quienes prefieren evitar costos de envío o el producto de una forma más inmediata.
# - Beneficios de entrega gratuita o tarifas exclusivas para clientes en áreas con alta interacción digital.
#
# 3. FOMENTAR COMPRA DE PRODUCTOS CON MENOR GASTO: con el fin de incentivar la venta de productos con un gasto menor por parte de los clientes se recomienda crear paquetes combinados entre productos con mayor gasto como la carne y el vino, con productos de menor gasto como las frutas y dulces. Adicionalmente, al observar que los clientes con hijos, gastan cantidades menores en los diferentes tipos de productos analizados, se puede ofrecer productos más económicos y prácticos, como paquetes o combos familiares que tengan precios competitivos adaptándose a los gastos más bajos de este grupo.También se pueden programar días de precios especiales, combinando promociones entre productos con mayor gasto al tiempo de productos de menor gastos.
#
#
# 4. CAMPAÑAS DIGITALES PERSONALIZADAS: creación de campañas publicitarias personalizadas, de acuerdo con el historial de compra y la edad, potencializando las entradas al sitio web, en especial dirigida a los clientes más jovenes de GoodTasteMaker.
